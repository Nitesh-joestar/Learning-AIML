# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import torchvision.transforms as transform
from torch.utils.tensorboard import SummaryWriter

# %%
class Discriminator(nn.Module):
    def __init__(self,img_dim):
        super().__init__()
        self.disc=nn.Sequential(
            nn.Linear(img_dim,128),
            nn.LeakyReLU(0.1),
            nn.Linear(128,1),
            nn.Sigmoid()
        )
    def forward(self,x):
        return self.disc(x)

# %%
class Generator(nn.Module):
    def __init__(self,z_dim,img_dim):
        super().__init__()
        self.gen=nn.Sequential(
            nn.Linear(z_dim,256),
            nn.LeakyReLU(0.1),
            nn.Linear(256,img_dim),
            nn.Tanh(),
        )
    def forward(self,x):
        return self.gen(x)

# %%
transform=transform.Compose([
    transform.ToTensor(),transform.Normalize(mean=0.5,std=0.5)
])

# %%
dataset=datasets.MNIST(root='data/',transform=transform,download=True)

# %%
device="cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
lr=3e-4
lr
# Out:
# 0.0003

# %%
z_dim=100
img_dim=28*28

# %%
gen=Generator(z_dim=z_dim,img_dim=img_dim).to(device)

# %%
disc=Discriminator(img_dim=img_dim).to(device)

# %%
batch_size=32

# %%
fixed_noise=torch.randn(batch_size,z_dim).to(device)

# %%
loader=DataLoader(dataset=dataset,batch_size=batch_size,shuffle=True)

# %%
opt_disc=optim.Adam(disc.parameters(),lr=lr)
opt_gen=optim.Adam(gen.parameters(),lr=lr)

# %%
criterion=nn.BCELoss()

# %%
writer_fake=SummaryWriter(f"runs/RGAN_MNIST/fake")
writer_real=SummaryWriter(f"runs/RGAN_MNIST/real")
step=0

# %%
for epochs in range(200):
    for batch_idx,(real,_) in enumerate(loader):
        real=real.view(-1,784).to(device)
        batch_size=real.shape[0]

        noise=torch.randn(batch_size,z_dim).to(device)
        fake=gen(noise)
        disc_real=disc(real).view(-1)
        lossD_real=criterion(disc_real,torch.ones_like(disc_real))
        disc_fake=disc(fake).view(-1)
        lossD_fake=criterion(disc_fake,torch.zeros_like(disc_fake))
        loss_D=(lossD_fake+lossD_real)/2#optmizing the difference between the fake and gen image pred is what disc is doing
        disc.zero_grad()
        loss_D.backward(retain_graph=True)
        opt_disc.step()

        output=disc(fake).view(-1)#fake is the image generated, optimizing the generated image loss is what generator is doing
        loss_G=criterion(output,torch.ones_like(output))
        gen.zero_grad()
        loss_G.backward()
        opt_gen.step()

        if batch_idx==0:
            print(f"Epoch:{epochs}")
            print(f"Loss Generator:{loss_G}\nLoss Discriminator:{loss_D}")

            with torch.no_grad():
                fake=gen(fixed_noise).reshape(-1,1,28,28)
                data=real.reshape(-1,1,28,28)
                img_grid_fake=torchvision.utils.make_grid(fake,normalize=True)
                img_grid_real=torchvision.utils.make_grid(real,normalize=True)
                writer_fake.add_image(
                    "MNIST_Generated_Images",img_grid_fake,global_step=step
                )
                writer_real.add_image(
                    "MNIST_Real_Images",img_grid_real,global_step=step
                )
                step+=1
# Out:
# Epoch:0
# Loss Generator:0.7285459041595459
# Loss Discriminator:0.6496785879135132
# Epoch:1
# Loss Generator:1.3258187770843506
# Loss Discriminator:0.42927712202072144
# Epoch:2
# Loss Generator:0.8693891763687134
# Loss Discriminator:0.6125895380973816
# Epoch:3
# Loss Generator:0.7162713408470154
# Loss Discriminator:0.831730306148529
# Epoch:4
# Loss Generator:1.039095163345337
# Loss Discriminator:0.4831978678703308
# Epoch:5
# Loss Generator:1.163738489151001
# Loss Discriminator:0.4721294641494751
# Epoch:6
# Loss Generator:0.5646107792854309
# Loss Discriminator:0.9028291702270508
# Epoch:7
# Loss Generator:1.0207855701446533
# Loss Discriminator:0.6893266439437866
# Epoch:8
# Loss Generator:1.0265462398529053
# Loss Discriminator:0.630061149597168
# Epoch:9
# Loss Generator:0.9728230834007263
# Loss Discriminator:0.5132157206535339
# Epoch:10
# Loss Generator:1.0659806728363037
# Loss Discriminator:0.6028090715408325
# Epoch:11
# Loss Generator:1.051514983177185
# Loss Discriminator:0.6069328188896179
# Epoch:12
# Loss Generator:1.200023889541626
# Loss Discriminator:0.5962522029876709
# Epoch:13
# Loss Generator:1.2138930559158325
# Loss Discriminator:0.48703211545944214
# Epoch:14
# Loss Generator:1.0710878372192383
# Loss Discriminator:0.723504900932312
# Epoch:15
# Loss Generator:0.9742722511291504
# Loss Discriminator:0.9087264537811279
# Epoch:16
# Loss Generator:0.9884447455406189
# Loss Discriminator:0.6338012218475342
# Epoch:17
# Loss Generator:0.8855644464492798
# Loss Discriminator:0.7291267514228821
# Epoch:18
# Loss Generator:1.1474047899246216
# Loss Discriminator:0.5162519812583923
# Epoch:19
# Loss Generator:1.3244824409484863
# Loss Discriminator:0.42168542742729187
# Epoch:20
# Loss Generator:1.062213659286499
# Loss Discriminator:0.8361825942993164
# Epoch:21
# Loss Generator:1.2937222719192505
# Loss Discriminator:0.5302326679229736
# Epoch:22
# Loss Generator:1.2201924324035645
# Loss Discriminator:0.5533389449119568
# Epoch:23
# Loss Generator:1.0753962993621826
# Loss Discriminator:0.7760769128799438
# Epoch:24
# Loss Generator:0.9685795307159424
# Loss Discriminator:0.7807484269142151
# Epoch:25
# Loss Generator:1.0499085187911987
# Loss Discriminator:0.6160300374031067
# Epoch:26
# Loss Generator:1.2274878025054932
# Loss Discriminator:0.6786046624183655
# Epoch:27
# Loss Generator:1.1638782024383545
# Loss Discriminator:0.619513988494873
# Epoch:28
# Loss Generator:0.7209609746932983
# Loss Discriminator:0.7097460031509399
# Epoch:29
# Loss Generator:0.9471795558929443
# Loss Discriminator:0.5350991487503052
# Epoch:30
# Loss Generator:1.1871232986450195
# Loss Discriminator:0.617727518081665
# Epoch:31
# Loss Generator:1.068167805671692
# Loss Discriminator:0.6504310965538025
# Epoch:32
# Loss Generator:0.919910192489624
# Loss Discriminator:0.68343585729599
# Epoch:33
# Loss Generator:0.9260425567626953
# Loss Discriminator:0.7084928154945374
# Epoch:34
# Loss Generator:0.9557567834854126
# Loss Discriminator:0.6511867642402649
# Epoch:35
# Loss Generator:1.0363514423370361
# Loss Discriminator:0.6354546546936035
# Epoch:36
# Loss Generator:0.9493758082389832
# Loss Discriminator:0.6883593797683716
# Epoch:37
# Loss Generator:0.9716478586196899
# Loss Discriminator:0.5564448833465576
# Epoch:38
# Loss Generator:1.071723222732544
# Loss Discriminator:0.5293906331062317
# Epoch:39
# Loss Generator:0.7658336162567139
# Loss Discriminator:0.7084689140319824
# Epoch:40
# Loss Generator:0.9893486499786377
# Loss Discriminator:0.671567440032959
# Epoch:41
# Loss Generator:1.2426844835281372
# Loss Discriminator:0.5485587120056152
# Epoch:42
# Loss Generator:1.0240178108215332
# Loss Discriminator:0.6599805951118469
# Epoch:43
# Loss Generator:0.8340804576873779
# Loss Discriminator:0.7063646912574768
# Epoch:44
# Loss Generator:0.8589215278625488
# Loss Discriminator:0.776740312576294
# Epoch:45
# Loss Generator:0.8331024646759033
# Loss Discriminator:0.6587176322937012
# Epoch:46
# Loss Generator:0.9712859392166138
# Loss Discriminator:0.7247235774993896
# Epoch:47
# Loss Generator:0.9268158674240112
# Loss Discriminator:0.7282471060752869
# Epoch:48
# Loss Generator:0.9705959558486938
# Loss Discriminator:0.6121082305908203
# Epoch:49
# Loss Generator:1.1136596202850342
# Loss Discriminator:0.6764627695083618
# Epoch:50
# Loss Generator:0.7667285203933716
# Loss Discriminator:0.7887880802154541
# Epoch:51
# Loss Generator:0.8633692860603333
# Loss Discriminator:0.6844893097877502
# Epoch:52
# Loss Generator:0.8181791305541992
# Loss Discriminator:0.7077239155769348
# Epoch:53
# Loss Generator:1.0242305994033813
# Loss Discriminator:0.562633216381073
# Epoch:54
# Loss Generator:0.8792620897293091
# Loss Discriminator:0.600448727607727
# Epoch:55
# Loss Generator:0.8699653148651123
# Loss Discriminator:0.7159536480903625
# Epoch:56
# Loss Generator:0.8673598170280457
# Loss Discriminator:0.6620635390281677
# Epoch:57
# Loss Generator:0.8397043943405151
# Loss Discriminator:0.6645132303237915
# Epoch:58
# Loss Generator:0.9099127650260925
# Loss Discriminator:0.6511820554733276
# Epoch:59
# Loss Generator:0.9977452158927917
# Loss Discriminator:0.583185076713562
# Epoch:60
# Loss Generator:0.9814112186431885
# Loss Discriminator:0.6049407720565796
# Epoch:61
# Loss Generator:1.070173978805542
# Loss Discriminator:0.6057088375091553
# Epoch:62
# Loss Generator:1.0840668678283691
# Loss Discriminator:0.65221107006073
# Epoch:63
# Loss Generator:1.081102967262268
# Loss Discriminator:0.6259544491767883
# Epoch:64
# Loss Generator:0.9479140043258667
# Loss Discriminator:0.6272485852241516
# Epoch:65
# Loss Generator:1.058164119720459
# Loss Discriminator:0.6040557622909546
# Epoch:66
# Loss Generator:0.9904671907424927
# Loss Discriminator:0.5661677122116089
# Epoch:67
# Loss Generator:0.9262080192565918
# Loss Discriminator:0.6607112884521484
# Epoch:68
# Loss Generator:0.9987528324127197
# Loss Discriminator:0.6374714374542236
# Epoch:69
# Loss Generator:0.9668720364570618
# Loss Discriminator:0.6531819105148315
# Epoch:70
# Loss Generator:0.9341172575950623
# Loss Discriminator:0.5928219556808472
# Epoch:71
# Loss Generator:0.6946754455566406
# Loss Discriminator:0.7378547787666321
# Epoch:72
# Loss Generator:0.8916639089584351
# Loss Discriminator:0.6690912842750549
# Epoch:73
# Loss Generator:0.826069712638855
# Loss Discriminator:0.7051023244857788
# Epoch:74
# Loss Generator:1.0840890407562256
# Loss Discriminator:0.7820135354995728
# Epoch:75
# Loss Generator:0.7015554904937744
# Loss Discriminator:0.7074490785598755
# Epoch:76
# Loss Generator:0.8843415975570679
# Loss Discriminator:0.6435631513595581
# Epoch:77
# Loss Generator:0.873242199420929
# Loss Discriminator:0.6079044342041016
# Epoch:78
# Loss Generator:1.1227091550827026
# Loss Discriminator:0.5959757566452026
# Epoch:79
# Loss Generator:1.24003267288208
# Loss Discriminator:0.5763945579528809
# Epoch:80
# Loss Generator:0.9339744448661804
# Loss Discriminator:0.6045913696289062
# Epoch:81
# Loss Generator:1.0585993528366089
# Loss Discriminator:0.5685825943946838
# Epoch:82
# Loss Generator:0.826189398765564
# Loss Discriminator:0.6186171770095825
# Epoch:83
# Loss Generator:1.0543386936187744
# Loss Discriminator:0.5077560544013977
# Epoch:84
# Loss Generator:0.7539478540420532
# Loss Discriminator:0.6132951974868774
# Epoch:85
# Loss Generator:0.9251853227615356
# Loss Discriminator:0.7254179120063782
# Epoch:86
# Loss Generator:0.8286231756210327
# Loss Discriminator:0.6890779733657837
# Epoch:87
# Loss Generator:1.0229707956314087
# Loss Discriminator:0.5706260204315186
# Epoch:88
# Loss Generator:0.8581002354621887
# Loss Discriminator:0.5783478617668152
# Epoch:89
# Loss Generator:0.9795428514480591
# Loss Discriminator:0.6199869513511658
# Epoch:90
# Loss Generator:1.0539698600769043
# Loss Discriminator:0.573114275932312
# Epoch:91
# Loss Generator:1.035376787185669
# Loss Discriminator:0.551270604133606
# Epoch:92
# Loss Generator:1.1488771438598633
# Loss Discriminator:0.5915248394012451
# Epoch:93
# Loss Generator:0.9035345315933228
# Loss Discriminator:0.6421792507171631
# Epoch:94
# Loss Generator:1.013395071029663
# Loss Discriminator:0.5991579294204712
# Epoch:95
# Loss Generator:0.9095859527587891
# Loss Discriminator:0.6263430118560791
# Epoch:96
# Loss Generator:0.8909008502960205
# Loss Discriminator:0.5801666975021362
# Epoch:97
# Loss Generator:0.8583540916442871
# Loss Discriminator:0.6506080627441406
# Epoch:98
# Loss Generator:1.0504543781280518
# Loss Discriminator:0.6012542843818665
# Epoch:99
# Loss Generator:1.1448466777801514
# Loss Discriminator:0.4821240305900574
# Epoch:100
# Loss Generator:0.9304465055465698
# Loss Discriminator:0.5348765254020691
# Epoch:101
# Loss Generator:0.9431363940238953
# Loss Discriminator:0.6928074955940247
# Epoch:102
# Loss Generator:1.0870342254638672
# Loss Discriminator:0.5872554779052734
# Epoch:103
# Loss Generator:1.0435888767242432
# Loss Discriminator:0.5414066314697266
# Epoch:104
# Loss Generator:1.0098111629486084
# Loss Discriminator:0.5955595970153809
# Epoch:105
# Loss Generator:0.8100600242614746
# Loss Discriminator:0.6455117464065552
# Epoch:106
# Loss Generator:1.294179081916809
# Loss Discriminator:0.507489800453186
# Epoch:107
# Loss Generator:1.1329365968704224
# Loss Discriminator:0.5675902962684631
# Epoch:108
# Loss Generator:1.0334173440933228
# Loss Discriminator:0.5517129898071289
# Epoch:109
# Loss Generator:1.0801916122436523
# Loss Discriminator:0.616757869720459
# Epoch:110
# Loss Generator:1.084375262260437
# Loss Discriminator:0.6765331029891968
# Epoch:111
# Loss Generator:1.0745136737823486
# Loss Discriminator:0.5649336576461792
# Epoch:112
# Loss Generator:1.0499424934387207
# Loss Discriminator:0.5598589181900024
# Epoch:113
# Loss Generator:1.0724244117736816
# Loss Discriminator:0.5376546382904053
# Epoch:114
# Loss Generator:0.9438176155090332
# Loss Discriminator:0.5731127858161926
# Epoch:115
# Loss Generator:1.0060402154922485
# Loss Discriminator:0.5238163471221924
# Epoch:116
# Loss Generator:1.4001388549804688
# Loss Discriminator:0.5413440465927124
# Epoch:117
# Loss Generator:1.0337364673614502
# Loss Discriminator:0.4852287173271179
# Epoch:118
# Loss Generator:0.950321614742279
# Loss Discriminator:0.5519631505012512
# Epoch:119
# Loss Generator:0.946220338344574
# Loss Discriminator:0.6234131455421448
# Epoch:120
# Loss Generator:1.0633021593093872
# Loss Discriminator:0.5261356830596924
# Epoch:121
# Loss Generator:1.1563804149627686
# Loss Discriminator:0.5892333388328552
# Epoch:122
# Loss Generator:0.9868214726448059
# Loss Discriminator:0.5827754735946655
# Epoch:123
# Loss Generator:0.9867417216300964
# Loss Discriminator:0.6117103099822998
# Epoch:124
# Loss Generator:0.9811525940895081
# Loss Discriminator:0.6053682565689087
# Epoch:125
# Loss Generator:1.1943318843841553
# Loss Discriminator:0.5545049905776978
# Epoch:126
# Loss Generator:1.1338485479354858
# Loss Discriminator:0.5834082961082458
# Epoch:127
# Loss Generator:1.215280294418335
# Loss Discriminator:0.45952165126800537
# Epoch:128
# Loss Generator:1.0715066194534302
# Loss Discriminator:0.6532913446426392
# Epoch:129
# Loss Generator:1.2018001079559326
# Loss Discriminator:0.5238420963287354
# Epoch:130
# Loss Generator:1.0202745199203491
# Loss Discriminator:0.5735410451889038
# Epoch:131
# Loss Generator:1.0357822179794312
# Loss Discriminator:0.5505341291427612
# Epoch:132
# Loss Generator:0.933837890625
# Loss Discriminator:0.6437442898750305
# Epoch:133
# Loss Generator:1.1826317310333252
# Loss Discriminator:0.5892009735107422
# Epoch:134
# Loss Generator:1.0939483642578125
# Loss Discriminator:0.607047975063324
# Epoch:135
# Loss Generator:1.0956141948699951
# Loss Discriminator:0.6297818422317505
# Epoch:136
# Loss Generator:1.265947699546814
# Loss Discriminator:0.48723363876342773
# Epoch:137
# Loss Generator:1.0217088460922241
# Loss Discriminator:0.6495229005813599
# Epoch:138
# Loss Generator:0.9233570098876953
# Loss Discriminator:0.5906608700752258
# Epoch:139
# Loss Generator:1.1589769124984741
# Loss Discriminator:0.5260962247848511
# Epoch:140
# Loss Generator:1.1143708229064941
# Loss Discriminator:0.5898542404174805
# Epoch:141
# Loss Generator:0.9274464249610901
# Loss Discriminator:0.612876296043396
# Epoch:142
# Loss Generator:1.2881108522415161
# Loss Discriminator:0.6074954867362976
# Epoch:143
# Loss Generator:0.9320352077484131
# Loss Discriminator:0.5712025165557861
# Epoch:144
# Loss Generator:0.9454951882362366
# Loss Discriminator:0.5776264667510986
# Epoch:145
# Loss Generator:1.1674636602401733
# Loss Discriminator:0.47185221314430237
# Epoch:146
# Loss Generator:1.069583535194397
# Loss Discriminator:0.6134252548217773
# Epoch:147
# Loss Generator:1.0639562606811523
# Loss Discriminator:0.5199955701828003
# Epoch:148
# Loss Generator:0.9507654905319214
# Loss Discriminator:0.6830615997314453
# Epoch:149
# Loss Generator:1.4379345178604126
# Loss Discriminator:0.5871952772140503
# Epoch:150
# Loss Generator:0.9686366319656372
# Loss Discriminator:0.5444437265396118
# Epoch:151
# Loss Generator:1.064661979675293
# Loss Discriminator:0.6172798871994019
# Epoch:152
# Loss Generator:1.3671389818191528
# Loss Discriminator:0.5087869763374329
# Epoch:153
# Loss Generator:1.2046687602996826
# Loss Discriminator:0.6067664623260498
# Epoch:154
# Loss Generator:1.173288106918335
# Loss Discriminator:0.5425964593887329
# Epoch:155
# Loss Generator:1.3167486190795898
# Loss Discriminator:0.605423092842102
# Epoch:156
# Loss Generator:0.9176153540611267
# Loss Discriminator:0.7041682600975037
# Epoch:157
# Loss Generator:1.0735647678375244
# Loss Discriminator:0.5300166606903076
# Epoch:158
# Loss Generator:1.0289745330810547
# Loss Discriminator:0.5440261960029602
# Epoch:159
# Loss Generator:1.3511075973510742
# Loss Discriminator:0.5889344811439514
# Epoch:160
# Loss Generator:1.1386315822601318
# Loss Discriminator:0.6504573822021484
# Epoch:161
# Loss Generator:1.131445288658142
# Loss Discriminator:0.5899869799613953
# Epoch:162
# Loss Generator:1.1583077907562256
# Loss Discriminator:0.5379685163497925
# Epoch:163
# Loss Generator:1.019392967224121
# Loss Discriminator:0.5576176643371582
# Epoch:164
# Loss Generator:1.0399105548858643
# Loss Discriminator:0.45739394426345825
# Epoch:165
# Loss Generator:0.9162867069244385
# Loss Discriminator:0.5851721167564392
# Epoch:166
# Loss Generator:1.2593660354614258
# Loss Discriminator:0.5069825053215027
# Epoch:167
# Loss Generator:1.1204683780670166
# Loss Discriminator:0.6024385690689087
# Epoch:168
# Loss Generator:1.0056064128875732
# Loss Discriminator:0.6591804623603821
# Epoch:169
# Loss Generator:1.0941846370697021
# Loss Discriminator:0.6787052154541016
# Epoch:170
# Loss Generator:1.2358593940734863
# Loss Discriminator:0.558029055595398
# Epoch:171
# Loss Generator:1.1304779052734375
# Loss Discriminator:0.5464226007461548
# Epoch:172
# Loss Generator:1.1444553136825562
# Loss Discriminator:0.6664928197860718
# Epoch:173
# Loss Generator:1.1861047744750977
# Loss Discriminator:0.5687423944473267
# Epoch:174
# Loss Generator:1.189021348953247
# Loss Discriminator:0.5559045076370239
# Epoch:175
# Loss Generator:1.2786511182785034
# Loss Discriminator:0.5199469327926636
# Epoch:176
# Loss Generator:1.0672860145568848
# Loss Discriminator:0.5705183744430542
# Epoch:177
# Loss Generator:1.0871294736862183
# Loss Discriminator:0.6088994741439819
# Epoch:178
# Loss Generator:1.290095567703247
# Loss Discriminator:0.49356549978256226
# Epoch:179
# Loss Generator:0.968956470489502
# Loss Discriminator:0.5865378975868225
# Epoch:180
# Loss Generator:1.2137718200683594
# Loss Discriminator:0.5282583832740784
# Epoch:181
# Loss Generator:1.1737558841705322
# Loss Discriminator:0.48795899748802185
# Epoch:182
# Loss Generator:1.3915340900421143
# Loss Discriminator:0.5682680606842041
# Epoch:183
# Loss Generator:0.9826515913009644
# Loss Discriminator:0.6700260043144226
# Epoch:184
# Loss Generator:1.4519356489181519
# Loss Discriminator:0.6182219982147217
# Epoch:185
# Loss Generator:1.1546247005462646
# Loss Discriminator:0.6040344834327698
# Epoch:186
# Loss Generator:0.8137133717536926
# Loss Discriminator:0.6437295079231262
# Epoch:187
# Loss Generator:1.2453657388687134
# Loss Discriminator:0.5400828123092651
# Epoch:188
# Loss Generator:0.88570237159729
# Loss Discriminator:0.6050342321395874
# Epoch:189
# Loss Generator:1.3528456687927246
# Loss Discriminator:0.5060057640075684
# Epoch:190
# Loss Generator:1.0058259963989258
# Loss Discriminator:0.583251953125
# Epoch:191
# Loss Generator:0.8885164856910706
# Loss Discriminator:0.6701250672340393
# Epoch:192
# Loss Generator:1.055264949798584
# Loss Discriminator:0.5882177948951721
# Epoch:193
# Loss Generator:1.0616202354431152
# Loss Discriminator:0.6058251857757568
# Epoch:194
# Loss Generator:1.08999502658844
# Loss Discriminator:0.5778602957725525
# Epoch:195
# Loss Generator:1.3492988348007202
# Loss Discriminator:0.6567528247833252
# Epoch:196
# Loss Generator:0.8948657512664795
# Loss Discriminator:0.5371164679527283
# Epoch:197
# Loss Generator:1.3479760885238647
# Loss Discriminator:0.4343775510787964
# Epoch:198
# Loss Generator:1.242697834968567
# Loss Discriminator:0.5573610663414001
# Epoch:199
# Loss Generator:1.4018665552139282
# Loss Discriminator:0.5668522715568542
