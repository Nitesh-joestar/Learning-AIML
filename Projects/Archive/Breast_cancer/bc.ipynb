# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier,XGBRFClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import f1_score,classification_report
from sklearn.model_selection import cross_val_predict

# %%
df=pd.read_csv('breast_cancer.csv')
df
# Out:
#       id        "diagnosis"   "radius_mean"   "texture_mean"  \
# 0      842302   M                     17.99            10.38
# 1      842517   M                     20.57            17.77
# 2    84300903   M                     19.69            21.25
# 3    84348301   M                     11.42            20.38
# 4    84358402   M                     20.29            14.34
# ..        ...           ...             ...              ...
# 564    926424   M                     21.56            22.39
# 565    926682   M                     20.13            28.25
# 566    926954   M                     16.60            28.08
# 567    927241   M                     20.60            29.33
# 568     92751   B                      7.76            24.54
#
#       "perimeter_mean"   "area_mean"   "smoothness_mean"   "compactness_mean"  \
# 0               122.80        1001.0             0.11840              0.27760
# ...

# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd

def clean_data(df):
    # Drop column: 'id     '
    df = df.drop(columns=['id     '])
    # Drop duplicate rows across all columns
    df = df.drop_duplicates()
    df = df.rename(columns={' "diagnosis"': 'diagnosis'})
    
    return df

# Loaded variable 'df' from URI: f:\Learngin-AIML\Projects\Breast_cancer\breast_cancer.csv
df = pd.read_csv(r'f:\Learngin-AIML\Projects\Breast_cancer\breast_cancer.csv')

df = clean_data(df.copy())
df.head()
# Out:
#     "diagnosis"  "radius_mean"  "texture_mean"  "perimeter_mean"  "area_mean"  \
# 0   M                    17.99           10.38            122.80       1001.0
# 1   M                    20.57           17.77            132.90       1326.0
# 2   M                    19.69           21.25            130.00       1203.0
# 3   M                    11.42           20.38             77.58        386.1
# 4   M                    20.29           14.34            135.10       1297.0
#
#    "smoothness_mean"  "compactness_mean"  "concavity_mean"  \
# 0            0.11840             0.27760            0.3001
# 1            0.08474             0.07864            0.0869
# 2            0.10960             0.15990            0.1974
# 3            0.14250             0.28390            0.2414
# 4            0.10030             0.13280            0.1980
#
#    "concave points_mean"  "symmetry_mean"  ...  "radius_worst"  \
# 0                0.14710           0.2419  ...           25.38
# ...

# %%
import pandas as pd

def clean_data(df):
    # Rename column ' "diagnosis"' to 'diagnosis'
    df = df.rename(columns={' "diagnosis"': 'diagnosis'})
    # Rename column ' "radius_mean"' to 'radius_mean'
    df = df.rename(columns={' "radius_mean"': 'radius_mean'})
    # Rename column ' "texture_mean"' to ' texture_mean'
    df = df.rename(columns={' "texture_mean"': ' texture_mean'})
    # Rename column ' "perimeter_mean"' to 'perimeter_mean'
    df = df.rename(columns={' "perimeter_mean"': 'perimeter_mean'})
    # Rename column ' "area_mean"' to 'area_mean'
    df = df.rename(columns={' "area_mean"': 'area_mean'})
    # Rename column ' "smoothness_mean"' to 'smoothness_mean'
    df = df.rename(columns={' "smoothness_mean"': 'smoothness_mean'})
    # Rename column ' "compactness_mean"' to 'compactness_mean'
    df = df.rename(columns={' "compactness_mean"': 'compactness_mean'})
    # Rename column ' "concavity_mean"' to 'concavity_mean'
    df = df.rename(columns={' "concavity_mean"': 'concavity_mean'})
    # Rename column ' "concave points_mean"' to 'concave_points_mean'
    df = df.rename(columns={' "concave points_mean"': 'concave_points_mean'})
    # Rename column ' "symmetry_mean"' to 'symmetry_mean'
    df = df.rename(columns={' "symmetry_mean"': 'symmetry_mean'})
    # Rename column ' "fractal_dimension_mean"' to 'fractal_dimension_mean'
    df = df.rename(columns={' "fractal_dimension_mean"': 'fractal_dimension_mean'})
    # Rename column ' "radius_se"' to 'radius_se'
    df = df.rename(columns={' "radius_se"': 'radius_se'})
    # Rename column ' "texture_se"' to 'texture_se'
    df = df.rename(columns={' "texture_se"': 'texture_se'})
    # Rename column ' "perimeter_se"' to 'perimeter_se'
    df = df.rename(columns={' "perimeter_se"': 'perimeter_se'})
    # Rename column ' "area_se"' to 'area_se'
    df = df.rename(columns={' "area_se"': 'area_se'})
    # Rename column ' "smoothness_se"' to 'smoothness_se'
    df = df.rename(columns={' "smoothness_se"': 'smoothness_se'})
    # Rename column ' "compactness_se"' to 'compactness_se'
    df = df.rename(columns={' "compactness_se"': 'compactness_se'})
    # Rename column ' "concavity_se"' to 'concavity_se'
    df = df.rename(columns={' "concavity_se"': 'concavity_se'})
    # Rename column ' "concave points_se"' to 'concave_points_se'
    df = df.rename(columns={' "concave points_se"': 'concave_points_se'})
    # Rename column ' "symmetry_se"' to 'symmetry_se'
    df = df.rename(columns={' "symmetry_se"': 'symmetry_se'})
    # Rename column ' "fractal_dimension_se"' to 'fractal_dimension_se'
    df = df.rename(columns={' "fractal_dimension_se"': 'fractal_dimension_se'})
    # Rename column ' "radius_worst"' to 'radius_worst'
    df = df.rename(columns={' "radius_worst"': 'radius_worst'})
    # Rename column ' "texture_worst"' to 'texture_worst'
    df = df.rename(columns={' "texture_worst"': 'texture_worst'})
    # Rename column ' "perimeter_worst"' to 'perimeter_worst'
    df = df.rename(columns={' "perimeter_worst"': 'perimeter_worst'})
    # Rename column ' "area_worst"' to 'area_worst'
    df = df.rename(columns={' "area_worst"': 'area_worst'})
    # Rename column ' "smoothness_worst"' to 'smoothness_worst'
    df = df.rename(columns={' "smoothness_worst"': 'smoothness_worst'})
    # Rename column ' "compactness_worst"' to 'compactness_worst'
    df = df.rename(columns={' "compactness_worst"': 'compactness_worst'})
    # Rename column ' "concavity_worst"' to 'concavity_worst'
    df = df.rename(columns={' "concavity_worst"': 'concavity_worst'})
    # Rename column ' "concave points_worst"' to 'concave_points_worst'
    df = df.rename(columns={' "concave points_worst"': 'concave_points_worst'})
    # Rename column ' "symmetry_worst"' to 'symmetry_worst'
    df = df.rename(columns={' "symmetry_worst"': 'symmetry_worst'})
    # Rename column ' "fractal_dimension_worst" ' to 'fractal_dimension_worst'
    df = df.rename(columns={' "fractal_dimension_worst" ': 'fractal_dimension_worst'})
    return df

# Loaded variable 'df' from URI: f:\Learngin-AIML\Projects\Breast_cancer\breast_cancer.csv
df = pd.read_csv(r'f:\Learngin-AIML\Projects\Breast_cancer\breast_cancer.csv')

df = clean_data(df.copy())
df.head()
# Out:
#     id          diagnosis  radius_mean   texture_mean  perimeter_mean  \
# 0    842302   M                  17.99          10.38          122.80
# 1    842517   M                  20.57          17.77          132.90
# 2  84300903   M                  19.69          21.25          130.00
# 3  84348301   M                  11.42          20.38           77.58
# 4  84358402   M                  20.29          14.34          135.10
#
#    area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     1001.0          0.11840           0.27760          0.3001
# 1     1326.0          0.08474           0.07864          0.0869
# 2     1203.0          0.10960           0.15990          0.1974
# 3      386.1          0.14250           0.28390          0.2414
# 4     1297.0          0.10030           0.13280          0.1980
#
#    concave_points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0              0.14710  ...         25.38          17.33           184.60
# ...

# %%
df
# Out:
#       id          diagnosis  radius_mean   texture_mean  perimeter_mean  \
# 0      842302   M                  17.99          10.38          122.80
# 1      842517   M                  20.57          17.77          132.90
# 2    84300903   M                  19.69          21.25          130.00
# 3    84348301   M                  11.42          20.38           77.58
# 4    84358402   M                  20.29          14.34          135.10
# ..        ...           ...          ...            ...             ...
# 564    926424   M                  21.56          22.39          142.00
# 565    926682   M                  20.13          28.25          131.20
# 566    926954   M                  16.60          28.08          108.30
# 567    927241   M                  20.60          29.33          140.10
# 568     92751   B                   7.76          24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %%
df['diagnosis']
# Out:
# 0       M
# 1       M
# 2       M
# 3       M
# 4       M
#            ...
# 564     M
# 565     M
# 566     M
# 567     M
# 568     B
# Name: diagnosis, Length: 569, dtype: object

# %%
encoder=LabelEncoder()
df['Diagnosis']=encoder.fit_transform(df['diagnosis'])
df.drop('diagnosis',axis=1,inplace=True)
df
# Out:
#       id       radius_mean   texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99          10.38          122.80     1001.0
# 1      842517        20.57          17.77          132.90     1326.0
# 2    84300903        19.69          21.25          130.00     1203.0
# 3    84348301        11.42          20.38           77.58      386.1
# 4    84358402        20.29          14.34          135.10     1297.0
# ..        ...          ...            ...             ...        ...
# 564    926424        21.56          22.39          142.00     1479.0
# 565    926682        20.13          28.25          131.20     1261.0
# 566    926954        16.60          28.08          108.30      858.1
# 567    927241        20.60          29.33          140.10     1265.0
# 568     92751         7.76          24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %%
y=df['Diagnosis']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: Diagnosis, Length: 569, dtype: int64

# %%
#X=df
#X.drop('Diagnosis',axis=1,inplace=True)
#X.drop('id     ',axis=1,inplace=True)
X
# Out:
#      radius_mean   texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99          10.38          122.80     1001.0          0.11840
# 1          20.57          17.77          132.90     1326.0          0.08474
# 2          19.69          21.25          130.00     1203.0          0.10960
# 3          11.42          20.38           77.58      386.1          0.14250
# 4          20.29          14.34          135.10     1297.0          0.10030
# ..           ...            ...             ...        ...              ...
# 564        21.56          22.39          142.00     1479.0          0.11100
# 565        20.13          28.25          131.20     1261.0          0.09780
# 566        16.60          28.08          108.30      858.1          0.08455
# 567        20.60          29.33          140.10     1265.0          0.11780
# 568         7.76          24.54           47.92      181.0          0.05263
#
# ...

# %%
#df=df.join(y)
df
# Out:
#       id       radius_mean   texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99          10.38          122.80     1001.0
# 1      842517        20.57          17.77          132.90     1326.0
# 2    84300903        19.69          21.25          130.00     1203.0
# 3    84348301        11.42          20.38           77.58      386.1
# 4    84358402        20.29          14.34          135.10     1297.0
# ..        ...          ...            ...             ...        ...
# 564    926424        21.56          22.39          142.00     1479.0
# 565    926682        20.13          28.25          131.20     1261.0
# 566    926954        16.60          28.08          108.30      858.1
# 567    927241        20.60          29.33          140.10     1265.0
# 568     92751         7.76          24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %% [markdown]
# ## Data exploration

# %%
corr=df.corr()
corr['Diagnosis']
# Out:
# id                         0.039769
# radius_mean                0.730029
#  texture_mean              0.415185
# perimeter_mean             0.742636
# area_mean                  0.708984
# smoothness_mean            0.358560
# compactness_mean           0.596534
# concavity_mean             0.696360
# concave_points_mean        0.776614
# symmetry_mean              0.330499
# fractal_dimension_mean    -0.012838
# radius_se                  0.567134
# texture_se                -0.008303
# perimeter_se               0.556141
# area_se                    0.548236
# smoothness_se             -0.067016
# compactness_se             0.292999
# concavity_se               0.253730
# concave_points_se          0.408042
# symmetry_se               -0.006522
# fractal_dimension_se       0.077972
# radius_worst               0.776454
# texture_worst              0.456903
# perimeter_worst            0.782914
# area_worst                 0.733825
# smoothness_worst           0.421465
# ...

# %%
X
# Out:
#      radius_mean   texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99          10.38          122.80     1001.0          0.11840
# 1          20.57          17.77          132.90     1326.0          0.08474
# 2          19.69          21.25          130.00     1203.0          0.10960
# 3          11.42          20.38           77.58      386.1          0.14250
# 4          20.29          14.34          135.10     1297.0          0.10030
# ..           ...            ...             ...        ...              ...
# 564        21.56          22.39          142.00     1479.0          0.11100
# 565        20.13          28.25          131.20     1261.0          0.09780
# 566        16.60          28.08          108.30      858.1          0.08455
# 567        20.60          29.33          140.10     1265.0          0.11780
# 568         7.76          24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# ## Model Selection

# %%
ran=RandomForestClassifier()
y_pred=cross_val_predict(ran,X,y,cv=5)
print(classification_report(y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97       357
#            1       0.96      0.93      0.95       212
#
#     accuracy                           0.96       569
#    macro avg       0.96      0.95      0.96       569
# weighted avg       0.96      0.96      0.96       569

# %%
xgb=XGBClassifier()
y_pred=cross_val_predict(xgb,X,y,cv=5)
print(classification_report(y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       357
#            1       0.97      0.96      0.96       212
#
#     accuracy                           0.97       569
#    macro avg       0.97      0.97      0.97       569
# weighted avg       0.97      0.97      0.97       569

# %%
xgbrf=XGBRFClassifier()
y_pred=cross_val_predict(xgbrf,X,y,cv=5)
print(classification_report(y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       357
#            1       0.94      0.94      0.94       212
#
#     accuracy                           0.96       569
#    macro avg       0.95      0.95      0.95       569
# weighted avg       0.96      0.96      0.96       569

# %%
lgbm=LGBMClassifier()
y_pred=cross_val_predict(lgbm,X,y,cv=5)
print(classification_report(y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       357
#            1       0.97      0.95      0.96       212
#
#     accuracy                           0.97       569
#    macro avg       0.97      0.97      0.97       569
# weighted avg       0.97      0.97      0.97       569
